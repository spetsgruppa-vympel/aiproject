# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

# %%
irefusetonamemyvariablesproperly = pd.read_csv("train.csv")
ihatepythongeneralconventionsandiwillbreakthemateverypossibleopportunity = pd.read_csv("test.csv")
print(irefusetonamemyvariablesproperly.head(10))
# Out:
#    Incident_ID    Country  Year        Attack Type     Target Industry  \
# 0          643    Germany  2017         Ransomware                  IT
# 1          701      Japan  2018         Ransomware           Education
# 2          227      Japan  2015            Malware          Healthcare
# 3         1698      Japan  2017      SQL Injection           Education
# 4         1011      China  2022           Phishing  Telecommunications
# 5         1573      Japan  2018         Ransomware           Education
# 6          777        USA  2019      SQL Injection                  IT
# 7         1731  Australia  2022  Man-in-the-Middle          Government
# 8         2827      Japan  2023               DDoS          Government
# 9         2229      Japan  2020               DDoS           Education
#
#    Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 0                          33.24                    550719  Hacker Group
# ...
